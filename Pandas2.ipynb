# %%
import pandas as pd
import numpy as np

# %%
 df = pd.read_csv('TitanicDataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df1 = pd.DataFrame = {
    'day':['1/1/2017','1/2/20017','1/3/2017'],
    'temprature':[32,35,28],
    'windspeed':[6,7,2],
    'event':['rain','sunny','snow']
}

df1
# Out:
# {'day': ['1/1/2017', '1/2/20017', '1/3/2017'],
#  'temprature': [32, 35, 28],
#  'windspeed': [6, 7, 2],
#  'event': ['rain', 'sunny', 'snow']}

# %%
df1['windspeed']
# Out:
# [6, 7, 2]

# %%
 weather_data = {
    ('1/1/2017','1/2/20017','1/3/2017'),
    (32,35,28),
    (6,7,2),
    ('rain','sunny','snow')
}

# %%
df2 = pd.DataFrame(weather_data, columns=['day''temprature','windspeed','event'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df2 = pd.DataFrame(weather_data, columns=['day''temprature','windspeed','event'])
#
# TypeError: 'dict' object is not callable

# %%
 weather_data = {
    ('1/1/2017','1/2/20017','1/3/2017'),
    (32,35,28),
    (6,7,2),
    ('rain','sunny','snow')
}
